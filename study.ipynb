# %%
import requests
headers = {'X-Api-Key':"DJz09RrCenTroEMVKgIZAdMv1M5OL5Vx1spifNjt"}
response = requests.get('https://api.api-ninjas.com/v2/quotes?categories=friendship', headers=headers)

# %%
response.text
# Out:
# '[{"quote": "Time doesn\'t take away from friendship, nor does separation.", "author": "Tennessee Williams", "work": "Memoirs", "categories": ["friendship", "time", "relationships", "wisdom"]}]'
